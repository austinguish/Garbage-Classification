# %%
import torchvision.models as models
import torch.optim as optim
import time
import torch
import torch.nn as nn
from Train import trainmodel
model = models.resnet34(pretrained=True)
time1 = time.time()
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
for param in model.parameters():
    param.requires_grad = False
    
model.fc = nn.Linear(512,6)
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
device = 7
model_name_list = ["transfer_resnet34_"]
lossfunc = torch.nn.CrossEntropyLoss().cuda(device)
file_name = model_name_list[0]+"ADAM"
print(file_name)
optimizer = optim.Adam(model.parameters())
trainmodel(model_name=model,loss = lossfunc,batchsize=36,opti=optimizer,\
           epoch_num=90,device_num=device,filename=file_name)
time2 = time.time()
print(time2-time1)
# Out:
# transfer_resnet34_ADAM
# 1768 328
# Epoch: 1
# Epoch: 001, Training: Loss: 1.4009, Accuracy: 47.5113%,Valid: Loss: 1.0119, Accuracy: 66.4634%,Time: 6.7435s
# Epoch: 2
# Epoch: 002, Training: Loss: 0.8485, Accuracy: 74.9434%,Valid: Loss: 0.7704, Accuracy: 75.0000%,Time: 6.5986s
# Epoch: 3
# Epoch: 003, Training: Loss: 0.6684, Accuracy: 79.6946%,Valid: Loss: 0.6810, Accuracy: 77.1341%,Time: 6.3659s
# Epoch: 4
# Epoch: 004, Training: Loss: 0.5692, Accuracy: 81.9570%,Valid: Loss: 0.5885, Accuracy: 81.0976%,Time: 6.3391s
# Epoch: 5
# Epoch: 005, Training: Loss: 0.5029, Accuracy: 85.4072%,Valid: Loss: 0.5565, Accuracy: 82.0122%,Time: 6.7350s
# Epoch: 6
# Epoch: 006, Training: Loss: 0.4602, Accuracy: 86.6516%,Valid: Loss: 0.5137, Accuracy: 81.7073%,Time: 6.8030s
# Epoch: 7
# Epoch: 007, Training: Loss: 0.4305, Accuracy: 87.3303%,Valid: Loss: 0.4921, Accuracy: 83.2317%,Time: 6.9360s
# Epoch: 8
# ...
