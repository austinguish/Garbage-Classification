# %%
import torch
import numpy
import os

for root, dirs, files in os.walk("./", topdown=False):
    for name in files:
        if name =="Untitled-checkpoint.ipynb":
            continue
        if name =="Untitled.ipynb":
            continue
        a = torch.load(name)
        epoch_info = numpy.array(a)
        print(name[:-3])
        print(sum(epoch_info[:,6:7])-sum(epoch_info[:, 5:6]))
# Out:
# transfer_resnet18_ADAMinfo
# [620.89428711]
# alexnet_36_ADAMinfo
# [264.77754211]
# transfer_mobilenet_ADAMinfo
# [295.58825684]
# transfer_vgg19_bn_ADAMinfo
# [601.32971191]
# densenet121_36_ADAMinfo
# [803.99926758]
# vgg19_bn_transfer_ADAM1info
# [618.8097229]
# alex_transfer_8_ADAMinfo
# [470.01159668]
# transfer_vgg16_bn_ADAMinfo
# [549.21969604]
# densenet12136rmspropinfo
# [775.80699158]
# vgg19_bn_36_ADAMinfo
# [561.83326721]
# alexnet_36_ADAMwdinfo
# [307.68041992]
# vgg11_bn36rmspropinfo
# [981.55859375]
# resnet101_36_ADAMinfo
# [940.49362183]
# vgg11_bn36SGDinfo
# [998.45414734]
# transfer_resnet101_ADAMinfo
# [1091.72674561]
# shufflenet_36_ADAMinfo
# [372.00297546]
# vgg19_bn36rmspropinfo
# [583.02999878]
# resnet18_36_ADAMinfo
# [407.0115509]
# mobilenet_v236rmspropinfo
# [431.16496277]
# transfer_resnet50_ADAMinfo
# [821.79959106]
# alexnet36adadeltainfo
# [309.64588928]
# resnet34_low36_ADAMinfo
# [325.61091614]
# transfer_resnet34_ADAMinfo
# [336.3430481]
# ...
