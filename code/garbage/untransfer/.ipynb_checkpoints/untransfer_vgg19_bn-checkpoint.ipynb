# %%
import torchvision.models as models
import torch.optim as optim
import time
import torch
import torch.nn as nn
from Train import trainmodel
time1 = time.time()
print(time1)
batch_size = [24]
device = 9
model_name_list = ["untran-vgg19bn"]
model1 = models.vgg19_bn(pretrained=False)
model1
# Out:
# 1591155862.8809783
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU(inplace=True)
#     (23): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (25): ReLU(inplace=True)
#     (26): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (27): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace=True)
#     (33): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (34): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (35): ReLU(inplace=True)
#     (36): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (37): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (38): ReLU(inplace=True)
#     (39): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU(inplace=True)
#     (43): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (44): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (45): ReLU(inplace=True)
#     (46): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (47): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (48): ReLU(inplace=True)
#     (49): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (50): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (51): ReLU(inplace=True)
#     (52): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
model1.classifier=nn.Sequential(nn.Linear(25088,4096),nn.ReLU(inplace = True),\
                               nn.Dropout(0.5),nn.Linear(4096,4096),\
                               nn.ReLU(inplace = True),nn.Dropout(0.5),nn.Linear(4096,6))
model1
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU(inplace=True)
#     (23): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (25): ReLU(inplace=True)
#     (26): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (27): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace=True)
#     (33): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (34): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (35): ReLU(inplace=True)
#     (36): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (37): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (38): ReLU(inplace=True)
#     (39): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU(inplace=True)
#     (43): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (44): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (45): ReLU(inplace=True)
#     (46): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (47): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (48): ReLU(inplace=True)
#     (49): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (50): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (51): ReLU(inplace=True)
#     (52): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=6, bias=True)
#   )
# )

# %%
model_list = [model1]
lossfunc = torch.nn.CrossEntropyLoss().cuda(device)
for size in batch_size:
    i = 0
    for models in model_list:
        file_name = model_name_list[i]
        print(file_name)
        optimizer = optim.Adam(models.parameters())
        trainmodel(model_name=models,loss = lossfunc,batchsize=size,opti=optimizer,\
                   epoch_num=50,device_num=device,filename=file_name)
        i+=1
# Out:
# untran-vgg19bn
# 1768 328
# Epoch: 1
# Epoch: 001, Training: Loss: 5.4391, Accuracy: 18.3258%,Valid: Loss: 1.7368, Accuracy: 25.6098%,Time: 24.2615s
# Epoch: 2
# Epoch: 002, Training: Loss: 1.7441, Accuracy: 20.4751%,Valid: Loss: 1.7083, Accuracy: 28.0488%,Time: 24.0374s
# Epoch: 3
# Epoch: 003, Training: Loss: 1.5695, Accuracy: 29.8643%,Valid: Loss: 1.4997, Accuracy: 38.1098%,Time: 24.5052s
# Epoch: 4
# Epoch: 004, Training: Loss: 1.4642, Accuracy: 38.4615%,Valid: Loss: 1.5701, Accuracy: 32.0122%,Time: 24.9655s
# Epoch: 5
# Epoch: 005, Training: Loss: 1.4474, Accuracy: 40.2149%,Valid: Loss: 1.4806, Accuracy: 41.7683%,Time: 24.9072s
# Epoch: 6
# Epoch: 006, Training: Loss: 1.3565, Accuracy: 44.9095%,Valid: Loss: 1.3835, Accuracy: 42.6829%,Time: 24.5020s
# Epoch: 7
# Epoch: 007, Training: Loss: 1.3031, Accuracy: 47.2285%,Valid: Loss: 1.3904, Accuracy: 43.9024%,Time: 24.7943s
# Epoch: 8
# Epoch: 008, Training: Loss: 1.3088, Accuracy: 46.6063%,Valid: Loss: 1.4970, Accuracy: 43.9024%,Time: 24.6877s
# Epoch: 9
# Epoch: 009, Training: Loss: 1.3219, Accuracy: 47.6810%,Valid: Loss: 1.5078, Accuracy: 42.3780%,Time: 24.8489s
# Epoch: 10
# Epoch: 010, Training: Loss: 1.2347, Accuracy: 51.4706%,Valid: Loss: 1.4689, Accuracy: 43.9024%,Time: 25.0075s
# Epoch: 11
# Epoch: 011, Training: Loss: 1.2430, Accuracy: 50.5656%,Valid: Loss: 1.4082, Accuracy: 44.5122%,Time: 25.2447s
# Epoch: 12
# Epoch: 012, Training: Loss: 1.2016, Accuracy: 52.4887%,Valid: Loss: 1.4699, Accuracy: 44.2073%,Time: 25.6076s
# Epoch: 034, Training: Loss: 0.1739, Accuracy: 94.4005%,Valid: Loss: 2.4270, Accuracy: 52.7439%,Time: 26.2803s
# Epoch: 35
# Epoch: 035, Training: Loss: 0.1458, Accuracy: 95.4751%,Valid: Loss: 2.6503, Accuracy: 53.9634%,Time: 25.5755s
# Epoch: 36
# Epoch: 036, Training: Loss: 0.1593, Accuracy: 94.6267%,Valid: Loss: 3.4842, Accuracy: 54.5732%,Time: 25.5288s
# Epoch: 37
# Epoch: 037, Training: Loss: 0.1437, Accuracy: 95.2489%,Valid: Loss: 2.7015, Accuracy: 52.1341%,Time: 25.7628s
# Epoch: 38
# Epoch: 038, Training: Loss: 0.1606, Accuracy: 94.9095%,Valid: Loss: 2.8698, Accuracy: 52.7439%,Time: 25.2868s
# Epoch: 39
# Epoch: 039, Training: Loss: 0.0536, Accuracy: 98.1900%,Valid: Loss: 3.7254, Accuracy: 52.7439%,Time: 25.0218s
# Epoch: 40
# Epoch: 040, Training: Loss: 0.0543, Accuracy: 98.2466%,Valid: Loss: 3.5142, Accuracy: 53.6585%,Time: 25.2001s
# Epoch: 41
# Epoch: 041, Training: Loss: 0.0910, Accuracy: 97.0023%,Valid: Loss: 3.5280, Accuracy: 51.2195%,Time: 25.3759s
# Epoch: 42
# Epoch: 042, Training: Loss: 0.0719, Accuracy: 97.3982%,Valid: Loss: 3.0815, Accuracy: 54.8780%,Time: 25.3539s
# Epoch: 43
# Epoch: 043, Training: Loss: 0.0741, Accuracy: 97.4548%,Valid: Loss: 3.4968, Accuracy: 51.5244%,Time: 25.1950s
# Epoch: 44
# Epoch: 044, Training: Loss: 0.1529, Accuracy: 94.9095%,Valid: Loss: 4.1456, Accuracy: 50.9146%,Time: 25.0256s
# Epoch: 45
# Epoch: 045, Training: Loss: 0.1305, Accuracy: 96.1538%,Valid: Loss: 2.8984, Accuracy: 53.6585%,Time: 25.1575s
# Epoch: 46
# Epoch: 046, Training: Loss: 0.1127, Accuracy: 96.6063%,Valid: Loss: 3.8986, Accuracy: 51.2195%,Time: 25.2527s
# Epoch: 47
# Epoch: 047, Training: Loss: 0.1545, Accuracy: 95.3054%,Valid: Loss: 2.9012, Accuracy: 53.0488%,Time: 24.8127s
# Epoch: 48
# Epoch: 048, Training: Loss: 0.0399, Accuracy: 98.5860%,Valid: Loss: 3.4165, Accuracy: 52.7439%,Time: 25.0120s
# Epoch: 49
# Epoch: 049, Training: Loss: 0.0246, Accuracy: 99.2647%,Valid: Loss: 3.2619, Accuracy: 54.2683%,Time: 25.0493s
# Epoch: 50
# Epoch: 050, Training: Loss: 0.0151, Accuracy: 99.4344%,Valid: Loss: 3.4260, Accuracy: 53.3537%,Time: 25.2216s
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-3e2f27104473> in <module>
#       8         optimizer = optim.Adam(models.parameters())
#       9         trainmodel(model_name=models,loss = lossfunc,batchsize=size,opti=optimizer,\
# ---> 10                    epoch_num=50,device_num=device,filename=file_name)
#      11         i+=1
#
# ~/gt/garbage/Train.py in trainmodel(model_name, loss, batchsize, opti, epoch_num, device_num, filename)
#      79     #torch.save(epoch_info,"./history/"+filename+"info.pt")
#      80     plot_save(epoch_info,filename,epoch)
# ---> 81     torch.cuda.empty_cache() #清除显存
#      82
#      83
#
# ~/.local/lib/python3.6/site-packages/torch/cuda/memory.py in empty_cache()
#      84     """
#      85     if is_initialized():
# ---> 86         torch._C._cuda_emptyCache()
#      87
#      88
#
# RuntimeError: CUDA error: out of memory
