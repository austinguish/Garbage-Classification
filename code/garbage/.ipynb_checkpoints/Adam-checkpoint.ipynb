# %% [markdown]
# # Garbage

# %%
import torchvision.models as models
import torch.optim as optim
from Train import trainmodel
from alexnet import *
from vgg import *
from densenet import *
from mobilenet import *
from ResNet import *
from shufflenetv2 import *
batch_size = [36]
device = 9
model_name_list = ["densenet161"]
model_list = [densenet121(pretrained=False)]
lossfunc = torch.nn.CrossEntropyLoss().cuda(device)
for size in batch_size:
    i = 0
    for models in model_list:
        file_name = model_name_list[i]+'_'+str(size)+'_'+"ADAMtest4"
        print(file_name)
        optimizer = optim.Adam(models.parameters(),weight_decay = 0.001)
        trainmodel(model_name=models,loss = lossfunc,batchsize=size,opti=optimizer,\
                   epoch_num=80,device_num=device,filename=file_name)
        i+=1
# Out:
# resnet18_36_ADAMtest4
# 1768 328
# Epoch: 1
# Epoch: 001, Training: Loss: 1.7260, Accuracy: 42.8167%,Valid: Loss: 1.5601, Accuracy: 50.9146%,Time: 5.1936s
# Epoch: 2
# Epoch: 002, Training: Loss: 1.5304, Accuracy: 39.7624%,Valid: Loss: 1.6210, Accuracy: 36.5854%,Time: 5.1560s
# Epoch: 3
# Epoch: 003, Training: Loss: 1.4314, Accuracy: 43.8348%,Valid: Loss: 1.5127, Accuracy: 43.5976%,Time: 5.0750s
# Epoch: 4
# Epoch: 004, Training: Loss: 1.3787, Accuracy: 46.3235%,Valid: Loss: 1.4952, Accuracy: 43.9024%,Time: 5.0148s
# Epoch: 5
# Epoch: 005, Training: Loss: 1.3817, Accuracy: 45.4751%,Valid: Loss: 1.5262, Accuracy: 42.0732%,Time: 5.0286s
# Epoch: 6
# Epoch: 006, Training: Loss: 1.3877, Accuracy: 44.9095%,Valid: Loss: 1.3155, Accuracy: 45.1220%,Time: 5.0181s
# Epoch: 7
# Epoch: 007, Training: Loss: 1.2697, Accuracy: 50.1131%,Valid: Loss: 1.2615, Accuracy: 49.3902%,Time: 5.2454s
# Epoch: 8
# ...
